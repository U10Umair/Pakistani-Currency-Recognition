# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base_dir = "/content/drive/MyDrive/Currency Notes detection dataset/Pakistani Currency Dataset"
os.listdir(base_dir)
# Out:
# ['50_back',
#  '500_front',
#  '500_back',
#  '5000_front',
#  '20_back',
#  '5000_back',
#  '50_front',
#  '20_front',
#  '10_front',
#  '10_back',
#  '1000_back',
#  '100_back',
#  '100_front',
#  '1000_front']

# %%
import cv2
import matplotlib.pyplot as plt
import os

sample_folder = os.path.join(base_dir, "100_front")
image_name = os.listdir(sample_folder)[0]

img_path = os.path.join(sample_folder, image_name)
img = cv2.imread(img_path)

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(831.5), np.float64(623.5), np.float64(-0.5))
